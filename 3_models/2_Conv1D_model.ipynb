# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import random 
from preprocessing_functions import *
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,accuracy_score

# %% [markdown]
# # Import and undersample the dataset

# %%
heart_attack_2020 = pd.read_csv(r'C:\Users\Hp\Documents\Machine_learning_projects\heart_attack_predictions\0_datasets\2020\heart_2020_cleaned.csv')
heart_attack_2020 = undersample_data(heart_attack_2020, 'HeartDisease')
print(heart_attack_2020.value_counts('HeartDisease'))
heart_attack_2020.head()
# Out:
# HeartDisease
# No     27373
# Yes    27373
# Name: count, dtype: int64
#        HeartDisease    BMI Smoking Stroke DiffWalking     Sex AgeCategory  \
# 111390           No  25.02      No     No          No  Female       50-54
# 250162           No  23.30      No     No          No  Female       50-54
# 230713           No  25.77     Yes     No          No    Male       45-49
# 153210           No  25.61     Yes    Yes          No  Female       25-29
# 149117           No  31.16     Yes     No         Yes  Female       65-69
#
#          Race Diabetic PhysicalActivity  GenHealth  SleepTime Asthma  \
# 111390  White       No              Yes       Good        6.0    Yes
# 250162  Black       No              Yes       Good        7.0     No
# 230713  White       No              Yes  Very good        4.0    Yes
# 153210  White      Yes               No       Fair        6.0     No
# 149117  Black       No              Yes       Fair        7.0     No
#
#        KidneyDisease SkinCancer
# 111390            No        Yes
# 250162            No         No
# 230713            No         No
# 153210            No         No
# 149117            No         No

# %% [markdown]
# # Model transforming BMI with log_min_max

# %% [markdown]
# ## Preprocessing

# %%
from preprocessing_functions import *

# numerical features
numerical_features = ['BMI','SleepTime']
# categorical features
categorical_features = ['Smoking', 'Stroke', 'DiffWalking', 'Sex','AgeCategory', 'Race', 'Diabetic', 
                        'PhysicalActivity', 'GenHealth', 'Asthma', 'KidneyDisease', 'SkinCancer']

heart_attack_2020 = heart_attack_2020[numerical_features + categorical_features + ['HeartDisease']]

# Encoding, scaling and train test split
(Train_df_encoded, Train_labels_encoded), (Valid_df_encoded, 
        Valid_labels_encoded), (Test_df_encoded, Test_labels_encoded) = preprocess_features(heart_attack_2020, one_hot_encoding=False,
                categorical_columns=categorical_features, numerical_tranformer = 'log_min_max',
                numerical_columns=numerical_features, target='HeartDisease')

print(f' train dataset length: {len(Train_df_encoded)}')
print(f' validation dataset length: {len(Valid_df_encoded)}')
print(f' test dataset length: {len(Test_df_encoded)}')

# Creating fast processing dataset
Dataset_train, Dataset_valid, Dataset_test = create_fast_preprocessing_odds(Train_df_encoded, Train_labels_encoded,
        Valid_df_encoded, Valid_labels_encoded, Test_df_encoded, Test_labels_encoded)

Dataset_train
# Out:
#  train dataset length: 46839
#  validation dataset length: 4074
#  test dataset length: 3833
# c:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 46), dtype=tf.float64, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ## Creating checkpoint callback

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_callback = ModelCheckpoint(
    filepath='conv1D_model_best.h5',
    save_weights_only=False,  
    monitor='val_accuracy',  
    save_best_only=True, 
    verbose=1  
)

# %% [markdown]
# ## Creating the model

# %%
from tensorflow.keras import layers

inputs = layers.Input(shape=(Train_df_encoded.shape[1],), name = 'input_layer')
x = layers.Reshape(target_shape=(Train_df_encoded.shape[1],1))(inputs) 
x = layers.BatchNormalization()(x)

x = layers.Conv1D(96, 4)(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.5)(x)

x = layers.Conv1D(64, 3)(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.4)(x)

x = layers.Flatten()(x)
x = layers.Dense(128)(x)
x = layers.Activation('relu')(x)
x = layers.Dense(64)(x)
x = layers.Activation('relu')(x)
x = layers.Dropout(0.4)(x)
outputs = layers.Dense(1, activation='sigmoid')(x)

model_conv1d = tf.keras.Model(inputs, outputs)

model_conv1d.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(),
    metrics=['accuracy']
)

# %%
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

conv1d_history = model_conv1d.fit(
                                Dataset_train,
                                epochs=50,
                                validation_data=Dataset_valid,
                                validation_steps=len(Dataset_valid),
                                callbacks=[checkpoint_callback]
                                )
# Out:
# Epoch 1/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.5190 - accuracy: 0.7520
# Epoch 1: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 15s 9ms/step - loss: 0.5189 - accuracy: 0.7521 - val_loss: 0.4894 - val_accuracy: 0.7641
# Epoch 2/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.5055 - accuracy: 0.7598
# Epoch 2: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.5053 - accuracy: 0.7600 - val_loss: 0.4849 - val_accuracy: 0.7666
# Epoch 3/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.5037 - accuracy: 0.7618
# Epoch 3: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.5036 - accuracy: 0.7618 - val_loss: 0.4877 - val_accuracy: 0.7614
# Epoch 4/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.5038 - accuracy: 0.7641
# Epoch 4: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.5037 - accuracy: 0.7641 - val_loss: 0.4844 - val_accuracy: 0.7651
# Epoch 5/50
# 1460/1464 [============================>.] - ETA: 0s - loss: 0.5011 - accuracy: 0.7643
# Epoch 5: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.5009 - accuracy: 0.7644 - val_loss: 0.4853 - val_accuracy: 0.7668
# Epoch 6/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4989 - accuracy: 0.7644
# Epoch 6: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4986 - accuracy: 0.7646 - val_loss: 0.4831 - val_accuracy: 0.7676
# Epoch 7/50
# 1460/1464 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7647
# Epoch 7: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4977 - accuracy: 0.7648 - val_loss: 0.4826 - val_accuracy: 0.7703
# Epoch 8/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4978 - accuracy: 0.7644
# Epoch 8: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4976 - accuracy: 0.7646 - val_loss: 0.4836 - val_accuracy: 0.7668
# Epoch 9/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4962 - accuracy: 0.7658
# Epoch 9: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4962 - accuracy: 0.7658 - val_loss: 0.4838 - val_accuracy: 0.7698
# Epoch 10/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4962 - accuracy: 0.7656
# Epoch 10: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4961 - accuracy: 0.7657 - val_loss: 0.4832 - val_accuracy: 0.7707
# Epoch 11/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4947 - accuracy: 0.7670
# Epoch 11: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4947 - accuracy: 0.7671 - val_loss: 0.4843 - val_accuracy: 0.7720
# Epoch 12/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4933 - accuracy: 0.7672
# Epoch 12: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4933 - accuracy: 0.7673 - val_loss: 0.4840 - val_accuracy: 0.7690
# Epoch 13/50
# 1462/1464 [============================>.] - ETA: 0s - loss: 0.4937 - accuracy: 0.7673
# Epoch 13: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4936 - accuracy: 0.7674 - val_loss: 0.4849 - val_accuracy: 0.7732
# Epoch 14/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4930 - accuracy: 0.7679
# Epoch 14: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4930 - accuracy: 0.7679 - val_loss: 0.4843 - val_accuracy: 0.7737
# Epoch 15/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4923 - accuracy: 0.7674
# Epoch 15: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4923 - accuracy: 0.7675 - val_loss: 0.4863 - val_accuracy: 0.7698
# Epoch 16/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4916 - accuracy: 0.7684
# Epoch 16: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4916 - accuracy: 0.7685 - val_loss: 0.4843 - val_accuracy: 0.7707
# Epoch 17/50
# 1458/1464 [============================>.] - ETA: 0s - loss: 0.4912 - accuracy: 0.7676
# Epoch 17: val_accuracy did not improve from 0.77393
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4910 - accuracy: 0.7678 - val_loss: 0.4857 - val_accuracy: 0.7722
# Epoch 18/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4905 - accuracy: 0.7679
# Epoch 18: val_accuracy improved from 0.77393 to 0.77590, saving model to conv1D_model_best.h5
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4903 - accuracy: 0.7681 - val_loss: 0.4828 - val_accuracy: 0.7759
# Epoch 19/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4899 - accuracy: 0.7693
# Epoch 19: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4897 - accuracy: 0.7695 - val_loss: 0.4848 - val_accuracy: 0.7712
# Epoch 20/50
# 1462/1464 [============================>.] - ETA: 0s - loss: 0.4887 - accuracy: 0.7698
# Epoch 20: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4885 - accuracy: 0.7699 - val_loss: 0.4845 - val_accuracy: 0.7734
# Epoch 21/50
# 1460/1464 [============================>.] - ETA: 0s - loss: 0.4883 - accuracy: 0.7711
# Epoch 21: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4883 - accuracy: 0.7711 - val_loss: 0.4853 - val_accuracy: 0.7734
# Epoch 22/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4892 - accuracy: 0.7703
# Epoch 22: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 9ms/step - loss: 0.4891 - accuracy: 0.7703 - val_loss: 0.4856 - val_accuracy: 0.7722
# Epoch 23/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4874 - accuracy: 0.7697
# Epoch 23: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4873 - accuracy: 0.7698 - val_loss: 0.4887 - val_accuracy: 0.7700
# Epoch 24/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4862 - accuracy: 0.7700
# Epoch 24: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4860 - accuracy: 0.7702 - val_loss: 0.4871 - val_accuracy: 0.7700
# Epoch 25/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4851 - accuracy: 0.7699
# Epoch 25: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4851 - accuracy: 0.7699 - val_loss: 0.4882 - val_accuracy: 0.7700
# Epoch 26/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.7723
# Epoch 26: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4853 - accuracy: 0.7723 - val_loss: 0.4879 - val_accuracy: 0.7710
# Epoch 27/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4848 - accuracy: 0.7718
# Epoch 27: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4847 - accuracy: 0.7718 - val_loss: 0.4891 - val_accuracy: 0.7680
# Epoch 28/50
# 1460/1464 [============================>.] - ETA: 0s - loss: 0.4837 - accuracy: 0.7713
# Epoch 28: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4836 - accuracy: 0.7713 - val_loss: 0.4909 - val_accuracy: 0.7705
# Epoch 29/50
# 1458/1464 [============================>.] - ETA: 0s - loss: 0.4843 - accuracy: 0.7713
# Epoch 29: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4840 - accuracy: 0.7716 - val_loss: 0.4911 - val_accuracy: 0.7695
# Epoch 30/50
# 1462/1464 [============================>.] - ETA: 0s - loss: 0.4814 - accuracy: 0.7741
# Epoch 30: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4813 - accuracy: 0.7742 - val_loss: 0.4920 - val_accuracy: 0.7698
# Epoch 31/50
# 1462/1464 [============================>.] - ETA: 0s - loss: 0.4830 - accuracy: 0.7719
# Epoch 31: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4828 - accuracy: 0.7720 - val_loss: 0.4918 - val_accuracy: 0.7693
# Epoch 32/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4804 - accuracy: 0.7740
# Epoch 32: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 9ms/step - loss: 0.4802 - accuracy: 0.7742 - val_loss: 0.4931 - val_accuracy: 0.7700
# Epoch 33/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.7717
# Epoch 33: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4812 - accuracy: 0.7717 - val_loss: 0.4940 - val_accuracy: 0.7695
# Epoch 34/50
# 1460/1464 [============================>.] - ETA: 0s - loss: 0.4806 - accuracy: 0.7722
# Epoch 34: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 13s 9ms/step - loss: 0.4804 - accuracy: 0.7724 - val_loss: 0.4930 - val_accuracy: 0.7690
# Epoch 35/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4803 - accuracy: 0.7734
# Epoch 35: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4803 - accuracy: 0.7733 - val_loss: 0.4950 - val_accuracy: 0.7703
# Epoch 36/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.7749
# Epoch 36: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4785 - accuracy: 0.7749 - val_loss: 0.4940 - val_accuracy: 0.7693
# Epoch 37/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4778 - accuracy: 0.7757
# Epoch 37: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4778 - accuracy: 0.7757 - val_loss: 0.4954 - val_accuracy: 0.7730
# Epoch 38/50
# 1462/1464 [============================>.] - ETA: 0s - loss: 0.4770 - accuracy: 0.7758
# Epoch 38: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4769 - accuracy: 0.7758 - val_loss: 0.4992 - val_accuracy: 0.7680
# Epoch 39/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4766 - accuracy: 0.7751
# Epoch 39: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4764 - accuracy: 0.7752 - val_loss: 0.4974 - val_accuracy: 0.7680
# Epoch 40/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4770 - accuracy: 0.7745
# Epoch 40: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4770 - accuracy: 0.7745 - val_loss: 0.4977 - val_accuracy: 0.7668
# Epoch 41/50
# 1461/1464 [============================>.] - ETA: 0s - loss: 0.4763 - accuracy: 0.7761
# Epoch 41: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4763 - accuracy: 0.7761 - val_loss: 0.4980 - val_accuracy: 0.7688
# Epoch 42/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4758 - accuracy: 0.7755
# Epoch 42: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4758 - accuracy: 0.7755 - val_loss: 0.4961 - val_accuracy: 0.7668
# Epoch 43/50
# 1458/1464 [============================>.] - ETA: 0s - loss: 0.4750 - accuracy: 0.7759
# Epoch 43: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4747 - accuracy: 0.7761 - val_loss: 0.4982 - val_accuracy: 0.7671
# Epoch 44/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4735 - accuracy: 0.7758
# Epoch 44: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4735 - accuracy: 0.7758 - val_loss: 0.5022 - val_accuracy: 0.7668
# Epoch 45/50
# 1459/1464 [============================>.] - ETA: 0s - loss: 0.4743 - accuracy: 0.7751
# Epoch 45: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4741 - accuracy: 0.7753 - val_loss: 0.5008 - val_accuracy: 0.7710
# Epoch 46/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4731 - accuracy: 0.7769
# Epoch 46: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4731 - accuracy: 0.7769 - val_loss: 0.5017 - val_accuracy: 0.7676
# Epoch 47/50
# 1464/1464 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7764
# Epoch 47: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4733 - accuracy: 0.7764 - val_loss: 0.5033 - val_accuracy: 0.7693
# Epoch 48/50
# 1458/1464 [============================>.] - ETA: 0s - loss: 0.4730 - accuracy: 0.7765
# Epoch 48: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4727 - accuracy: 0.7767 - val_loss: 0.5061 - val_accuracy: 0.7700
# Epoch 49/50
# 1463/1464 [============================>.] - ETA: 0s - loss: 0.4716 - accuracy: 0.7767
# Epoch 49: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 8ms/step - loss: 0.4715 - accuracy: 0.7767 - val_loss: 0.5066 - val_accuracy: 0.7685
# Epoch 50/50
# 1458/1464 [============================>.] - ETA: 0s - loss: 0.4700 - accuracy: 0.7773
# Epoch 50: val_accuracy did not improve from 0.77590
# 1464/1464 [==============================] - 12s 9ms/step - loss: 0.4698 - accuracy: 0.7775 - val_loss: 0.5055 - val_accuracy: 0.7698

# %% [markdown]
# ### Evaluating the model

# %%
from helper_functions import plot_loss_curve  

plot_loss_curve(conv1d_history)
# Out:
# 0

# %%
best_conv1d_model = tf.keras.models.load_model(r'C:\Users\Hp\Documents\Machine_learning_projects\heart_attack_predictions\4_saved_models\conv1D_model_best.h5')
test_pred = best_conv1d_model.predict(Dataset_test)

print(best_conv1d_model.evaluate(Dataset_test))
print(classification_report(tf.round(test_pred), Test_labels_encoded))
# Out:
# 120/120 [==============================] - 0s 2ms/step
# 120/120 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7553
# [0.501553475856781, 0.7552830576896667]
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.77      0.74      1704
#          1.0       0.80      0.74      0.77      2129
#
#     accuracy                           0.76      3833
#    macro avg       0.75      0.76      0.75      3833
# weighted avg       0.76      0.76      0.76      3833

# %%
from tensorflow.keras.utils import plot_model
plot_model(best_conv1d_model, show_shapes=True)
